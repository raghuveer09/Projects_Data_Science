# %%
##project on walmart sales and demand

##Importing Required Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp

#READING THE DATA
df=pd.read_csv("Walmart_Store_sales.csv")
pd.set_option("display.max_columns",None)
#df.reset_index(drop=True,inplace=True)

df.head(5)


df.shape

(6435, 8)

#df.info()

df["Date"]=pd.to_datetime(df['Date'])

df1=df.groupby(["Store"])["Weekly_Sales"].sum()

df1=pd.DataFrame(df1)

df1['Weekly_Sales']=df1["Weekly_Sales"].astype("float")

df1['Weekly_Sales']=df1["Weekly_Sales"].astype("int")

df1=df1.reset_index()

a=max(df1['Weekly_Sales'])
a1=df1[df1['Weekly_Sales']==a]
print("The Store With Max Sales is :",a1)
b=min(df1['Weekly_Sales'])
b1=df1[df1['Weekly_Sales']==b]
print("The stre with min sales is :",b1)

# Which store has maximum standard deviation
data_std = pd.DataFrame(df.groupby('Store')['Weekly_Sales'].std().sort_values(ascending=False))
print("The store has maximum standard deviation is "+str(data_std.head(1).index[0])+" with {0:.0f} $".format(data_std.head(1).Weekly_Sales[data_std.head(1).index[0]]))





# Coefficient of mean to standard deviation
coef_mean_std = pd.DataFrame(df.groupby('Store')['Weekly_Sales'].std() / df.groupby('Store')['Weekly_Sales'].mean())
coef_mean_std = coef_mean_std.rename(columns={'Weekly_Sales':'Coefficient of mean to standard deviation'})
print(coef_mean_std)


##store q3 2012 comparisions growth rate


import datetime as dt

df["month"]=df["Date"].dt.month

df["Year"]=df["Date"].dt.year

df3=pd.DataFrame(df)

df4=df3[df3["Year"]==2012]

df_10=df4[df4["month"]==10]

df_10_1=pd.DataFrame(df_10)

df_10_2=df_10_1.groupby(['Store'])['Weekly_Sales'].sum()

df_10_3=pd.DataFrame(df_10_2)

df_11=df4[df4["month"]==11]

df_11_1=pd.DataFrame(df_11)

df_11_2=df_11_1.groupby(['Store'])['Weekly_Sales'].sum()

df_11_3=pd.DataFrame(df_11_2)

df_12=df4[df4["month"]==12]

df_12_1=pd.DataFrame(df_12)

df_12_2=df_12_1.groupby(['Store'])['Weekly_Sales'].sum()

df_12_3=pd.DataFrame(df_12_2)

quarter_df=pd.concat([df_10_3,df_11_3,df_12_3])

q3_2012=quarter_df.groupby(['Store']).sum()

q3_2012=q3_2012.rename(columns={"Weekly_Sales":"Quarterly_Sales_3"})

q3_2012=pd.DataFrame(q3_2012)

df_7=df4[df4["month"]==7]

df_71=pd.DataFrame(df_7)

df_72=df_71.groupby(['Store'])['Weekly_Sales'].sum()

df_73=pd.DataFrame(df_72)

df_8=df4[df4["month"]==8]

df_81=pd.DataFrame(df_8)

df_82=df_81.groupby(['Store'])['Weekly_Sales'].sum()

df_83=pd.DataFrame(df_82)

df_9=df4[df4["month"]==9]

df_91=pd.DataFrame(df_9)

df_92=df_91.groupby(['Store'])['Weekly_Sales'].sum()

df_93=pd.DataFrame(df_92)

q2=pd.concat([df_73,df_83,df_93])

q2_2012=q2.groupby(['Store']).sum()

q2_2012=q2_2012.rename(columns={"Weekly_Sales":"Quarterly_Sales_2"})

q2_2012=pd.DataFrame(q2_2012)

quarter_comp=pd.concat([q2_2012,q3_2012],axis=1)

quarter_comp['difference']=(quarter_comp['Quarterly_Sales_3']-quarter_comp['Quarterly_Sales_2'])
quarter_comp['Sales_Growth']=(quarter_comp['Quarterly_Sales_3']/quarter_comp['Quarterly_Sales_2'])-1

quarter_comp



##Quarter 0 ####
#month 1#

df_1=df4[df4["month"]==1]

df_1_1=pd.DataFrame(df_1)

df_1_2=df_1_1.groupby(['Store'])['Weekly_Sales'].sum()

df_1_3=pd.DataFrame(df_1_2)

#month 2#

df_2=df4[df4["month"]==2]

df_2_1=pd.DataFrame(df_2)

df_2_2=df_2_1.groupby(['Store'])['Weekly_Sales'].sum()

df_2_3=pd.DataFrame(df_2_2)

#month 3#

df_3=df4[df4["month"]==3]

df_3_1=pd.DataFrame(df_3)

df_3_2=df_3_1.groupby(['Store'])['Weekly_Sales'].sum()

df_3_3=pd.DataFrame(df_3_2)

#quarter concatenation##

quarter_df=pd.concat([df_1_3,df_2_3,df_3_3])

q0_2012=quarter_df.groupby(['Store']).sum()

q0_2012=q0_2012.rename(columns={"Weekly_Sales":"Quarterly_Sales_0"})

q0_2012=pd.DataFrame(q0_2012)

###Quarter 1###
#month 4#

df_4=df4[df4["month"]==4]

df_4_1=pd.DataFrame(df_4)

df_4_2=df_4_1.groupby(['Store'])['Weekly_Sales'].sum()

df_4_3=pd.DataFrame(df_4_2)

#month 5#

df_5=df4[df4["month"]==5]

df_5_1=pd.DataFrame(df_5)

df_5_2=df_5_1.groupby(['Store'])['Weekly_Sales'].sum()

df_5_3=pd.DataFrame(df_5_2)

#month 6#

df_6=df4[df4["month"]==6]

df_6_1=pd.DataFrame(df_6)

df_6_2=df_6_1.groupby(['Store'])['Weekly_Sales'].sum()

df_6_3=pd.DataFrame(df_6_2)

#quarter concatenation##

q1=pd.concat([df_4_3,df_5_3,df_6_3])

q1_2012=q1.groupby(['Store']).sum()

q1_2012=q1_2012.rename(columns={"Weekly_Sales":"Quarterly_Sales_1"})

q1_2012=pd.DataFrame(q1_2012)

year_2012_df=pd.concat([q0_2012,q1_2012,q2_2012,q3_2012],axis=1)
#year_2012_df


#####__Month_Wise__######
#####################
#####################

month_1_2012=pd.concat([df_1_3])
month_1_2012=month_1_2012.rename(columns={'Weekly_Sales':'month_1_Sales'})

month_2_2012=pd.concat([df_2_3])
month_2_2012=month_2_2012.rename(columns={'Weekly_Sales':'month_2_Sales'})


month_3_2012=pd.concat([df_3_3])
month_3_2012=month_3_2012.rename(columns={'Weekly_Sales':'month_3_Sales'})

month_4_2012=pd.concat([df_4_3])
month_4_2012=month_4_2012.rename(columns={'Weekly_Sales':'month_4_Sales'})
#monthly_2012_df

month_5_2012=pd.concat([df_5_3])
month_5_2012=month_5_2012.rename(columns={'Weekly_Sales':'month_5_Sales'})
#monthly_2012_df=
month_6_2012=pd.concat([df_6_3])
month_6_2012=month_6_2012.rename(columns={'Weekly_Sales':'month_6_Sales'})

month_7_2012=pd.concat([df_73])
month_7_2012=month_7_2012.rename(columns={'Weekly_Sales':'month_7_Sales'})

month_8_2012=pd.concat([df_83])
month_8_2012=month_8_2012.rename(columns={'Weekly_Sales':'month_8_Sales'})

month_9_2012=pd.concat([df_93])
month_9_2012=month_9_2012.rename(columns={'Weekly_Sales':'month_9_Sales'})

month_10_2012=pd.concat([df_10_3])
month_10_2012=month_10_2012.rename(columns={'Weekly_Sales':'month_10_Sales'})

month_11_2012=pd.concat([df_11_3])
month_11_2012=month_11_2012.rename(columns={'Weekly_Sales':'month_11_Sales'})

month_12_2012=pd.concat([df_12_3])
month_12_2012=month_12_2012.rename(columns={'Weekly_Sales':'month_12_Sales'})

monthly_2012_df=pd.concat([month_1_2012,month_2_2012,month_3_2012,month_4_2012,month_5_2012,month_6_2012,month_7_2012,month_8_2012,month_9_2012,month_10_2012,month_11_2012,month_12_2012],axis=1)
#monthly_2012_df
# Out:
# The Store With Max Sales is :     Store  Weekly_Sales
# 19     20     301397792
# The stre with min sales is :     Store  Weekly_Sales
# 32     33      37160221
# The store has maximum standard deviation is 14 with 317570 $
#        Coefficient of mean to standard deviation
# Store
# 1                                       0.100292
# 2                                       0.123424
# 3                                       0.115021
# 4                                       0.127083
# 5                                       0.118668
# 6                                       0.135823
# 7                                       0.197305
# 8                                       0.116953
# 9                                       0.126895
# 10                                      0.159133
# 11                                      0.122262
# 12                                      0.137925
# 13                                      0.132514
# 14                                      0.157137
# ...

# %% [markdown]
# store q3 2012 comparisions growth rate

# %%
m=max(quarter_comp['Sales_Growth'])
q2_q3_top=quarter_comp[quarter_comp['Sales_Growth']==m]
print("Best Performer of q3 When cmpared with previous quarer ::")
print(q2_q3_top)
n=max(quarter_comp['Quarterly_Sales_3'])
q3_top=quarter_comp[quarter_comp['Quarterly_Sales_3']==n]
print("quarter_3 top sales store is::")
print(q3_top)
# Out:
# Best Performer of q3 When cmpared with previous quarer ::
#        Quarterly_Sales_2  Quarterly_Sales_3  difference  Sales_Growth
# Store
# 14            20140430.4        10647575.27 -9492855.13     -0.471333
# quarter_3 top sales store is::
#        Quarterly_Sales_2  Quarterly_Sales_3   difference  Sales_Growth
# Store
# 4            25652119.35        13075576.88 -12576542.47     -0.490273

# %%
###Monthly and Quarterly Insights###
####################################
m_1= max(month_1_2012['month_1_Sales'])
month_1_highest_sales=month_1_2012[month_1_2012['month_1_Sales']==m_1]
month_1_highest_sales



m_2=max(month_2_2012['month_2_Sales'])
month_2_highest_sales=month_2_2012[month_2_2012['month_2_Sales']==m_2]
month_2_highest_sales


m_3=max(month_3_2012['month_3_Sales'])
month_3_highest_sales=month_3_2012[month_3_2012['month_3_Sales']==m_3]
month_3_highest_sales



m_4=max(month_4_2012['month_4_Sales'])
month_4_highest_sales=month_4_2012[month_4_2012['month_4_Sales']==m_4]
month_4_highest_sales


m_5=max(month_5_2012['month_5_Sales'])
month_5_highest_sales=month_5_2012[month_5_2012['month_5_Sales']==m_5]
month_5_highest_sales


m_6=max(month_6_2012['month_6_Sales'])
month_6_highest_sales=month_6_2012[month_6_2012['month_6_Sales']==m_6]
month_6_highest_sales


m_7=max(month_7_2012['month_7_Sales'])
month_7_highest_sales=month_7_2012[month_7_2012['month_7_Sales']==m_7]
month_7_highest_sales


m_8=max(month_8_2012['month_8_Sales'])
month_8_highest_sales=month_8_2012[month_8_2012['month_8_Sales']==m_8]
month_8_highest_sales


m_9=max(month_9_2012['month_9_Sales'])
month_9_highest_sales=month_9_2012[month_9_2012['month_9_Sales']==m_9]
month_9_highest_sales


m_10=max(month_10_2012['month_10_Sales'])
month_10_highest_sales=month_10_2012[month_10_2012['month_10_Sales']==m_10]
month_10_highest_sales


m_11=max(month_11_2012['month_11_Sales'])
month_11_highest_sales=month_11_2012[month_11_2012['month_11_Sales']==m_11]
month_11_highest_sales


m_12=max(month_12_2012['month_12_Sales'])
month_12_highest_sales=month_12_2012[month_12_2012['month_12_Sales']==m_12]
month_12_highest_sales
# Out:
#        month_12_Sales
# Store
# 20         2162951.36

# %%
###Monthly and Quarterly Insights###
####################################
m_1= min(month_1_2012['month_1_Sales'])
month_1_least_sales=month_1_2012[month_1_2012['month_1_Sales']==m_1]
month_1_least_sales



m_2=min(month_2_2012['month_2_Sales'])
month_2_least_sales=month_2_2012[month_2_2012['month_2_Sales']==m_2]
month_2_least_sales


m_3=min(month_3_2012['month_3_Sales'])
month_3_least_sales=month_3_2012[month_3_2012['month_3_Sales']==m_3]
month_3_least_sales



m_4=min(month_4_2012['month_4_Sales'])
month_4_least_sales=month_4_2012[month_4_2012['month_4_Sales']==m_4]
month_4_least_sales


m_5=min(month_5_2012['month_5_Sales'])
month_5_least_sales=month_5_2012[month_5_2012['month_5_Sales']==m_5]
month_5_least_sales


m_6=min(month_6_2012['month_6_Sales'])
month_6_least_sales=month_6_2012[month_6_2012['month_6_Sales']==m_6]
month_6_least_sales


m_7=min(month_7_2012['month_7_Sales'])
month_7_least_sales=month_7_2012[month_7_2012['month_7_Sales']==m_7]
month_7_least_sales


m_8=min(month_8_2012['month_8_Sales'])
month_8_least_sales=month_8_2012[month_8_2012['month_8_Sales']==m_8]
month_8_least_sales


m_9=min(month_9_2012['month_9_Sales'])
month_9_least_sales=month_9_2012[month_9_2012['month_9_Sales']==m_9]
month_9_least_sales


m_10=min(month_10_2012['month_10_Sales'])
month_10_least_sales=month_10_2012[month_10_2012['month_10_Sales']==m_10]
month_10_least_sales


m_11=min(month_11_2012['month_11_Sales'])
month_11_least_sales=month_11_2012[month_11_2012['month_11_Sales']==m_11]
month_11_least_sales


m_12=min(month_12_2012['month_12_Sales'])
month_12_least_sales=month_12_2012[month_12_2012['month_12_Sales']==m_12]
month_12_least_sales
# Out:
#        month_12_Sales
# Store
# 33          291781.15

# %%
####Quarterly_insights_2012_#####
#################################

q_0= max(q0_2012['Quarterly_Sales_0'])
q0_highest_sales=q0_2012[q0_2012['Quarterly_Sales_0']==q_0]
q0_highest_sales

q_1= max(q1_2012['Quarterly_Sales_1'])
q1_highest_sales=q1_2012[q1_2012['Quarterly_Sales_1']==q_1]
q1_highest_sales

q_2= max(q2_2012['Quarterly_Sales_2'])
q2_highest_sales=q2_2012[q2_2012['Quarterly_Sales_2']==q_2]
q2_highest_sales

q_3= max(q3_2012['Quarterly_Sales_3'])
q3_highest_sales=q3_2012[q3_2012['Quarterly_Sales_3']==q_3]
q3_highest_sales


###__Lowest__Sales__##
q_0_min= min(q0_2012['Quarterly_Sales_0'])
q0_least_sales=q0_2012[q0_2012['Quarterly_Sales_0']==q_0]
q0_least_sales

q_1_min= min(q1_2012['Quarterly_Sales_1'])
q1_least_sales=q1_2012[q1_2012['Quarterly_Sales_1']==q_1]
q1_least_sales

q_2_min= min(q2_2012['Quarterly_Sales_2'])
q2_least_sales=q2_2012[q2_2012['Quarterly_Sales_2']==q_2]
q2_least_sales

q_3= min(q3_2012['Quarterly_Sales_3'])
q3_least_sales=q3_2012[q3_2012['Quarterly_Sales_3']==q_3]
q3_least_sales
# Out:
#        Quarterly_Sales_3
# Store
# 33            1676072.53

# %% [markdown]
# 2011___###########

# %%
df_2011=df3[df3["Year"]==2011]

df_10=df_2011[df_2011["month"]==10]

df_10_1=pd.DataFrame(df_10)

df_10_2=df_10_1.groupby(['Store'])['Weekly_Sales'].sum()

df_10_3=pd.DataFrame(df_10_2)

##month 11

df_11=df_2011[df_2011["month"]==11]

df_11_1=pd.DataFrame(df_11)

df_11_2=df_11_1.groupby(['Store'])['Weekly_Sales'].sum()

df_11_3=pd.DataFrame(df_11_2)

#month 12

df_12=df_2011[df_2011["month"]==12]

df_12_1=pd.DataFrame(df_12)

df_12_2=df_12_1.groupby(['Store'])['Weekly_Sales'].sum()

df_12_3=pd.DataFrame(df_12_2)

quarter_df=pd.concat([df_10_3,df_11_3,df_12_3])

q3_2011=quarter_df.groupby(['Store']).sum()

q3_2011=q3_2011.rename(columns={"Weekly_Sales":"Quarterly_Sales_3"})

q3_2011=pd.DataFrame(q3_2011)

#month 7

df_7=df_2011[df_2011["month"]==7]

df_71=pd.DataFrame(df_7)

df_72=df_71.groupby(['Store'])['Weekly_Sales'].sum()

df_73=pd.DataFrame(df_72)

#month 8

df_8=df_2011[df_2011["month"]==8]

df_81=pd.DataFrame(df_8)

df_82=df_81.groupby(['Store'])['Weekly_Sales'].sum()

df_83=pd.DataFrame(df_82)

# mnth 9

df_9=df_2011[df_2011["month"]==9]

df_91=pd.DataFrame(df_9)

df_92=df_91.groupby(['Store'])['Weekly_Sales'].sum()

df_93=pd.DataFrame(df_92)


q2=pd.concat([df_73,df_83,df_93])

q2_2011=q2.groupby(['Store']).sum()

q2_2011=q2_2011.rename(columns={"Weekly_Sales":"Quarterly_Sales_2"})

q2_2011=pd.DataFrame(q2_2011)

quarter_comp=pd.concat([q2_2012,q3_2012],axis=1)





##Quarter 0 ####
#month 1#

df_1=df_2011[df_2011["month"]==1]

df_1_1=pd.DataFrame(df_1)

df_1_2=df_1_1.groupby(['Store'])['Weekly_Sales'].sum()

df_1_3=pd.DataFrame(df_1_2)

#month 2#

df_2=df_2011[df_2011["month"]==2]

df_2_1=pd.DataFrame(df_2)

df_2_2=df_2_1.groupby(['Store'])['Weekly_Sales'].sum()

df_2_3=pd.DataFrame(df_2_2)

#month 3#

df_3=df_2011[df_2011["month"]==3]

df_3_1=pd.DataFrame(df_3)

df_3_2=df_3_1.groupby(['Store'])['Weekly_Sales'].sum()

df_3_3=pd.DataFrame(df_3_2)

#quarter concatenation##

quarter_df=pd.concat([df_1_3,df_2_3,df_3_3])

q0_2011=quarter_df.groupby(['Store']).sum()

q0_2011=q0_2011.rename(columns={"Weekly_Sales":"Quarterly_Sales_0"})

q0_2011=pd.DataFrame(q0_2011)

###Quarter 1###
#month 4#

df_4=df_2011[df_2011["month"]==4]

df_4_1=pd.DataFrame(df_4)

df_4_2=df_4_1.groupby(['Store'])['Weekly_Sales'].sum()

df_4_3=pd.DataFrame(df_4_2)

#month 5#

df_5=df_2011[df_2011["month"]==5]

df_5_1=pd.DataFrame(df_5)

df_5_2=df_5_1.groupby(['Store'])['Weekly_Sales'].sum()

df_5_3=pd.DataFrame(df_5_2)

#month 6#

df_6=df_2011[df_2011["month"]==6]

df_6_1=pd.DataFrame(df_6)

df_6_2=df_6_1.groupby(['Store'])['Weekly_Sales'].sum()

df_6_3=pd.DataFrame(df_6_2)

#quarter concatenation##

q1=pd.concat([df_4_3,df_5_3,df_6_3])

q1_2011=q1.groupby(['Store']).sum()

q1_2011=q1_2011.rename(columns={"Weekly_Sales":"Quarterly_Sales_1"})

q1_2011=pd.DataFrame(q1_2011)
year_2011_df=pd.concat([q0_2011,q1_2011,q2_2011,q3_2011],axis=1)
#year_2012_df


#####__Month_Wise__######
#####################
#####################

month_1_2011=pd.concat([df_1_3])
month_1_2011=month_1_2011.rename(columns={'Weekly_Sales':'month_1_Sales_2011'})

month_2_2011=pd.concat([df_2_3])
month_2_2011=month_2_2011.rename(columns={'Weekly_Sales':'month_2_Sales_2011'})


month_3_2011=pd.concat([df_3_3])
month_3_2011=month_3_2011.rename(columns={'Weekly_Sales':'month_3_Sales_2011'})

month_4_2011=pd.concat([df_4_3])
month_4_2011=month_4_2011.rename(columns={'Weekly_Sales':'month_4_Sales_2011'})
#monthly_2012_df

month_5_2011=pd.concat([df_5_3])
month_5_2011=month_5_2011.rename(columns={'Weekly_Sales':'month_5_Sales_2011'})
#monthly_2012_df=
month_6_2011=pd.concat([df_6_3])
month_6_2011=month_6_2011.rename(columns={'Weekly_Sales':'month_6_Sales_2011'})

month_7_2011=pd.concat([df_73])
month_7_2011=month_7_2011.rename(columns={'Weekly_Sales':'month_7_Sales_2011'})

month_8_2011=pd.concat([df_83])
month_8_2011=month_8_2011.rename(columns={'Weekly_Sales':'month_8_Sales_2011'})

month_9_2011=pd.concat([df_93])
month_9_2011=month_9_2011.rename(columns={'Weekly_Sales':'month_9_Sales_2011'})

month_10_2011=pd.concat([df_10_3])
month_10_2011=month_10_2011.rename(columns={'Weekly_Sales':'month_10_Sales_2011'})

month_11_2011=pd.concat([df_11_3])
month_11_2011=month_11_2011.rename(columns={'Weekly_Sales':'month_11_Sales_2011'})

month_12_2011=pd.concat([df_12_3])
month_12_2011=month_12_2011.rename(columns={'Weekly_Sales':'month_12_Sales_2011'})

monthly_2011_df=pd.concat([month_1_2011,month_2_2011,month_3_2011,month_4_2011,month_5_2011,month_6_2011,month_7_2011,month_8_2011,month_9_2011,month_10_2011,month_11_2011,month_12_2011],axis=1)
#monthly_2011_df


###Monthly and Quarterly Insights###
####################################
m_1= max(month_1_2011['month_1_Sales_2011'])
month_1_highest_sales=month_1_2011[month_1_2011['month_1_Sales_2011']==m_1]
month_1_highest_sales



m_2=max(month_2_2011['month_2_Sales_2011'])
month_2_highest_sales=month_2_2011[month_2_2011['month_2_Sales_2011']==m_2]
month_2_highest_sales


m_3=max(month_3_2011['month_3_Sales_2011'])
month_3_highest_sales=month_3_2011[month_3_2011['month_3_Sales_2011']==m_3]
month_3_highest_sales



m_4=max(month_4_2011['month_4_Sales_2011'])
month_4_highest_sales=month_4_2011[month_4_2011['month_4_Sales_2011']==m_4]
month_4_highest_sales


m_5=max(month_5_2011['month_5_Sales_2011'])
month_5_highest_sales=month_5_2011[month_5_2011['month_5_Sales_2011']==m_5]
month_5_highest_sales


m_6=max(month_6_2011['month_6_Sales_2011'])
month_6_highest_sales=month_6_2011[month_6_2011['month_6_Sales_2011']==m_6]
month_6_highest_sales


m_7=max(month_7_2011['month_7_Sales_2011'])
month_7_highest_sales=month_7_2011[month_7_2011['month_7_Sales_2011']==m_7]
month_7_highest_sales


m_8=max(month_8_2011['month_8_Sales_2011'])
month_8_highest_sales=month_8_2011[month_8_2011['month_8_Sales_2011']==m_8]
month_8_highest_sales


m_9=max(month_9_2011['month_9_Sales_2011'])
month_9_highest_sales=month_9_2011[month_9_2011['month_9_Sales_2011']==m_9]
month_9_highest_sales


m_10=max(month_10_2011['month_10_Sales_2011'])
month_10_highest_sales=month_10_2011[month_10_2011['month_10_Sales_2011']==m_10]
month_10_highest_sales


m_11=max(month_11_2011['month_11_Sales_2011'])
month_11_highest_sales=month_11_2011[month_11_2011['month_11_Sales_2011']==m_11]
month_11_highest_sales


m_12=max(month_12_2011['month_12_Sales_2011'])
month_12_highest_sales=month_12_2011[month_12_2011['month_12_Sales_2011']==m_12]
month_12_highest_sales


###Monthly and Quarterly Insights###
####################################
m_1= min(month_1_2011['month_1_Sales_2011'])
month_1_highest_sales=month_1_2011[month_1_2011['month_1_Sales_2011']==m_1]
month_1_highest_sales



m_2=min(month_2_2011['month_2_Sales_2011'])
month_2_highest_sales=month_2_2011[month_2_2011['month_2_Sales_2011']==m_2]
month_2_highest_sales


m_3=min(month_3_2011['month_3_Sales_2011'])
month_3_highest_sales=month_3_2011[month_3_2011['month_3_Sales_2011']==m_3]
month_3_highest_sales



m_4=min(month_4_2011['month_4_Sales_2011'])
month_4_highest_sales=month_4_2011[month_4_2011['month_4_Sales_2011']==m_4]
month_4_highest_sales


m_5=min(month_5_2011['month_5_Sales_2011'])
month_5_highest_sales=month_5_2011[month_5_2011['month_5_Sales_2011']==m_5]
month_5_highest_sales


m_6=min(month_6_2011['month_6_Sales_2011'])
month_6_highest_sales=month_6_2011[month_6_2011['month_6_Sales_2011']==m_6]
month_6_highest_sales


m_7=min(month_7_2011['month_7_Sales_2011'])
month_7_highest_sales=month_7_2011[month_7_2011['month_7_Sales_2011']==m_7]
month_7_highest_sales


m_8=min(month_8_2011['month_8_Sales_2011'])
month_8_highest_sales=month_8_2011[month_8_2011['month_8_Sales_2011']==m_8]
month_8_highest_sales


m_9=min(month_9_2011['month_9_Sales_2011'])
month_9_highest_sales=month_9_2011[month_9_2011['month_9_Sales_2011']==m_9]
month_9_highest_sales


m_10=min(month_10_2011['month_10_Sales_2011'])
month_10_highest_sales=month_10_2011[month_10_2011['month_10_Sales_2011']==m_10]
month_10_highest_sales


m_11=min(month_11_2011['month_11_Sales_2011'])
month_11_highest_sales=month_11_2011[month_11_2011['month_11_Sales_2011']==m_11]
month_11_highest_sales


m_12=min(month_12_2011['month_12_Sales_2011'])
month_12_highest_sales=month_12_2011[month_12_2011['month_12_Sales_2011']==m_12]
month_12_highest_sales




####Quarterly_insights_2012_#####
#################################

q_0= max(q0_2011['Quarterly_Sales_0'])
q0_highest_sales=q0_2011[q0_2011['Quarterly_Sales_0']==q_0]
q0_highest_sales

q_1= max(q1_2011['Quarterly_Sales_1'])
q1_highest_sales=q1_2011[q1_2011['Quarterly_Sales_1']==q_1]
q1_highest_sales

q_2= max(q2_2011['Quarterly_Sales_2'])
q2_highest_sales=q2_2011[q2_2011['Quarterly_Sales_2']==q_2]
q2_highest_sales

q_3= max(q3_2011['Quarterly_Sales_3'])
q3_highest_sales=q3_2011[q3_2011['Quarterly_Sales_3']==q_3]
q3_highest_sales


###__Lowest__Sales__##
q_0_min= min(q0_2011['Quarterly_Sales_0'])
q0_least_sales=q0_2011[q0_2011['Quarterly_Sales_0']==q_0]
q0_least_sales

q_1_min= min(q1_2011['Quarterly_Sales_1'])
q1_least_sales=q1_2011[q1_2011['Quarterly_Sales_1']==q_1]
q1_least_sales

q_2_min= min(q2_2011['Quarterly_Sales_2'])
q2_least_sales=q2_2011[q2_2011['Quarterly_Sales_2']==q_2]
q2_least_sales

q_3= min(q3_2011['Quarterly_Sales_3'])
q3_least_sales=q3_2011[q3_2011['Quarterly_Sales_3']==q_3]
q3_least_sales
# Out:
#        Quarterly_Sales_3
# Store
# 33            3328104.55

# %% [markdown]
# 2010_____########

# %%
df_2010=df3[df3["Year"]==2010]

df_10=df_2010[df_2010["month"]==10]

df_10_1=pd.DataFrame(df_10)

df_10_2=df_10_1.groupby(['Store'])['Weekly_Sales'].sum()

df_10_3=pd.DataFrame(df_10_2)

##month 11

df_11=df_2010[df_2010["month"]==11]

df_11_1=pd.DataFrame(df_11)

df_11_2=df_11_1.groupby(['Store'])['Weekly_Sales'].sum()

df_11_3=pd.DataFrame(df_11_2)

#month 12

df_12=df_2010[df_2010["month"]==12]

df_12_1=pd.DataFrame(df_12)

df_12_2=df_12_1.groupby(['Store'])['Weekly_Sales'].sum()

df_12_3=pd.DataFrame(df_12_2)

quarter_df=pd.concat([df_10_3,df_11_3,df_12_3])

q3_2010=quarter_df.groupby(['Store']).sum()

q3_2010=q3_2010.rename(columns={"Weekly_Sales":"Quarterly_Sales_3"})

q3_2010=pd.DataFrame(q3_2010)

#month 7

df_7=df_2010[df_2010["month"]==7]

df_71=pd.DataFrame(df_7)

df_72=df_71.groupby(['Store'])['Weekly_Sales'].sum()

df_73=pd.DataFrame(df_72)

#month 8

df_8=df_2010[df_2010["month"]==8]

df_81=pd.DataFrame(df_8)

df_82=df_81.groupby(['Store'])['Weekly_Sales'].sum()

df_83=pd.DataFrame(df_82)

# mnth 9

df_9=df_2010[df_2010["month"]==9]

df_91=pd.DataFrame(df_9)

df_92=df_91.groupby(['Store'])['Weekly_Sales'].sum()

df_93=pd.DataFrame(df_92)


q2=pd.concat([df_73,df_83,df_93])

q2_2010=q2.groupby(['Store']).sum()

q2_2010=q2_2010.rename(columns={"Weekly_Sales":"Quarterly_Sales_2"})

q2_2010=pd.DataFrame(q2_2010)

quarter_comp=pd.concat([q2_2010,q3_2010],axis=1)





##Quarter 0 ####
#month 1#

df_1=df_2010[df_2010["month"]==1]

df_1_1=pd.DataFrame(df_1)

df_1_2=df_1_1.groupby(['Store'])['Weekly_Sales'].sum()

df_1_3=pd.DataFrame(df_1_2)

#month 2#

df_2=df_2010[df_2010["month"]==2]

df_2_1=pd.DataFrame(df_2)

df_2_2=df_2_1.groupby(['Store'])['Weekly_Sales'].sum()

df_2_3=pd.DataFrame(df_2_2)

#month 3#

df_3=df_2010[df_2010["month"]==3]

df_3_1=pd.DataFrame(df_3)

df_3_2=df_3_1.groupby(['Store'])['Weekly_Sales'].sum()

df_3_3=pd.DataFrame(df_3_2)

#quarter concatenation##

quarter_df=pd.concat([df_1_3,df_2_3,df_3_3])

q0_2010=quarter_df.groupby(['Store']).sum()

q0_2010=q0_2010.rename(columns={"Weekly_Sales":"Quarterly_Sales_0"})

q0_2010=pd.DataFrame(q0_2010)

###Quarter 1###
#month 4#

df_4=df_2010[df_2010["month"]==4]

df_4_1=pd.DataFrame(df_4)

df_4_2=df_4_1.groupby(['Store'])['Weekly_Sales'].sum()

df_4_3=pd.DataFrame(df_4_2)

#month 5#

df_5=df_2010[df_2010["month"]==5]

df_5_1=pd.DataFrame(df_5)

df_5_2=df_5_1.groupby(['Store'])['Weekly_Sales'].sum()

df_5_3=pd.DataFrame(df_5_2)

#month 6#

df_6=df_2010[df_2010["month"]==6]

df_6_1=pd.DataFrame(df_6)

df_6_2=df_6_1.groupby(['Store'])['Weekly_Sales'].sum()

df_6_3=pd.DataFrame(df_6_2)

#quarter concatenation##

q1=pd.concat([df_4_3,df_5_3,df_6_3])

q1_2010=q1.groupby(['Store']).sum()

q1_2010=q1_2010.rename(columns={"Weekly_Sales":"Quarterly_Sales_1"})

q1_2010=pd.DataFrame(q1_2010)
year_2010_df=pd.concat([q0_2010,q1_2010,q2_2010,q3_2010],axis=1)
#year_2012_df


#####__Month_Wise__######
#####################
#####################

month_1_2010=pd.concat([df_1_3])
month_1_2010=month_1_2010.rename(columns={'Weekly_Sales':'month_1_Sales_2010'})

month_2_2010=pd.concat([df_2_3])
month_2_2010=month_2_2010.rename(columns={'Weekly_Sales':'month_2_Sales_2010'})


month_3_2010=pd.concat([df_3_3])
month_3_2010=month_3_2010.rename(columns={'Weekly_Sales':'month_3_Sales_2010'})

month_4_2010=pd.concat([df_4_3])
month_4_2010=month_4_2010.rename(columns={'Weekly_Sales':'month_4_Sales_2010'})
#monthly_2012_df

month_5_2010=pd.concat([df_5_3])
month_5_2010=month_5_2010.rename(columns={'Weekly_Sales':'month_5_Sales_2010'})
#monthly_2012_df=
month_6_2010=pd.concat([df_6_3])
month_6_2010=month_6_2010.rename(columns={'Weekly_Sales':'month_6_Sales_2010'})

month_7_2010=pd.concat([df_73])
month_7_2010=month_7_2010.rename(columns={'Weekly_Sales':'month_7_Sales_2010'})

month_8_2010=pd.concat([df_83])
month_8_2010=month_8_2010.rename(columns={'Weekly_Sales':'month_8_Sales_2010'})

month_9_2010=pd.concat([df_93])
month_9_2010=month_9_2010.rename(columns={'Weekly_Sales':'month_9_Sales_2010'})

month_10_2010=pd.concat([df_10_3])
month_10_2010=month_10_2010.rename(columns={'Weekly_Sales':'month_10_Sales_2010'})

month_11_2010=pd.concat([df_11_3])
month_11_2010=month_11_2010.rename(columns={'Weekly_Sales':'month_11_Sales_2010'})

month_12_2010=pd.concat([df_12_3])
month_12_2010=month_12_2010.rename(columns={'Weekly_Sales':'month_12_Sales_2010'})

monthly_2010_df=pd.concat([month_1_2010,month_2_2010,month_3_2010,month_4_2010,month_5_2010,month_6_2010,month_7_2010,month_8_2010,month_9_2010,month_10_2010,month_11_2010,month_12_2010],axis=1)
#monthly_2010_df

###Monthly and Quarterly Insights###
####################################
m_1= max(month_1_2010['month_1_Sales_2010'])
month_1_highest_sales=month_1_2010[month_1_2010['month_1_Sales_2010']==m_1]
month_1_highest_sales



m_2=max(month_2_2010['month_2_Sales_2010'])
month_2_highest_sales=month_2_2010[month_2_2010['month_2_Sales_2010']==m_2]
month_2_highest_sales


m_3=max(month_3_2010['month_3_Sales_2010'])
month_3_highest_sales=month_3_2010[month_3_2010['month_3_Sales_2010']==m_3]
month_3_highest_sales



m_4=max(month_4_2010['month_4_Sales_2010'])
month_4_highest_sales=month_4_2010[month_4_2010['month_4_Sales_2010']==m_4]
month_4_highest_sales


m_5=max(month_5_2010['month_5_Sales_2010'])
month_5_highest_sales=month_5_2010[month_5_2010['month_5_Sales_2010']==m_5]
month_5_highest_sales


m_6=max(month_6_2010['month_6_Sales_2010'])
month_6_highest_sales=month_6_2010[month_6_2010['month_6_Sales_2010']==m_6]
month_6_highest_sales


m_7=max(month_7_2010['month_7_Sales_2010'])
month_7_highest_sales=month_7_2010[month_7_2010['month_7_Sales_2010']==m_7]
month_7_highest_sales


m_8=max(month_8_2010['month_8_Sales_2010'])
month_8_highest_sales=month_8_2010[month_8_2010['month_8_Sales_2010']==m_8]
month_8_highest_sales


m_9=max(month_9_2010['month_9_Sales_2010'])
month_9_highest_sales=month_9_2010[month_9_2010['month_9_Sales_2010']==m_9]
month_9_highest_sales


m_10=max(month_10_2010['month_10_Sales_2010'])
month_10_highest_sales=month_10_2010[month_10_2010['month_10_Sales_2010']==m_10]
month_10_highest_sales


m_11=max(month_11_2010['month_11_Sales_2010'])
month_11_highest_sales=month_11_2010[month_11_2010['month_11_Sales_2010']==m_11]
month_11_highest_sales


m_12=max(month_12_2010['month_12_Sales_2010'])
month_12_highest_sales=month_12_2010[month_12_2010['month_12_Sales_2010']==m_12]
month_12_highest_sales



###Monthly and Quarterly Insights###
####################################
m_1= min(month_1_2010['month_1_Sales_2010'])
month_1_highest_sales=month_1_2010[month_1_2010['month_1_Sales_2010']==m_1]
month_1_highest_sales



m_2=min(month_2_2010['month_2_Sales_2010'])
month_2_highest_sales=month_2_2010[month_2_2010['month_2_Sales_2010']==m_2]
month_2_highest_sales


m_3=min(month_3_2010['month_3_Sales_2010'])
month_3_highest_sales=month_3_2010[month_3_2010['month_3_Sales_2010']==m_3]
month_3_highest_sales



m_4=min(month_4_2010['month_4_Sales_2010'])
month_4_highest_sales=month_4_2010[month_4_2010['month_4_Sales_2010']==m_4]
month_4_highest_sales


m_5=min(month_5_2010['month_5_Sales_2010'])
month_5_highest_sales=month_5_2010[month_5_2010['month_5_Sales_2010']==m_5]
month_5_highest_sales


m_6=min(month_6_2010['month_6_Sales_2010'])
month_6_highest_sales=month_6_2010[month_6_2010['month_6_Sales_2010']==m_6]
month_6_highest_sales


m_7=min(month_7_2010['month_7_Sales_2010'])
month_7_highest_sales=month_7_2010[month_7_2010['month_7_Sales_2010']==m_7]
month_7_highest_sales


m_8=min(month_8_2010['month_8_Sales_2010'])
month_8_highest_sales=month_8_2010[month_8_2010['month_8_Sales_2010']==m_8]
month_8_highest_sales


m_9=min(month_9_2010['month_9_Sales_2010'])
month_9_highest_sales=month_9_2010[month_9_2010['month_9_Sales_2010']==m_9]
month_9_highest_sales


m_10=min(month_10_2010['month_10_Sales_2010'])
month_10_highest_sales=month_10_2010[month_10_2010['month_10_Sales_2010']==m_10]
month_10_highest_sales


m_11=min(month_11_2010['month_11_Sales_2010'])
month_11_highest_sales=month_11_2010[month_11_2010['month_11_Sales_2010']==m_11]
month_11_highest_sales


m_12=min(month_12_2010['month_12_Sales_2010'])
month_12_highest_sales=month_12_2010[month_12_2010['month_12_Sales_2010']==m_12]
month_12_highest_sales



####Quarterly_insights_2012_#####
#################################

q_0= max(q0_2010['Quarterly_Sales_0'])
q0_highest_sales=q0_2010[q0_2010['Quarterly_Sales_0']==q_0]
q0_highest_sales

q_1= max(q1_2010['Quarterly_Sales_1'])
q1_highest_sales=q1_2010[q1_2010['Quarterly_Sales_1']==q_1]
q1_highest_sales

q_2= max(q2_2010['Quarterly_Sales_2'])
q2_highest_sales=q2_2010[q2_2010['Quarterly_Sales_2']==q_2]
q2_highest_sales

q_3= max(q3_2010['Quarterly_Sales_3'])
q3_highest_sales=q3_2010[q3_2010['Quarterly_Sales_3']==q_3]
q3_highest_sales


###__Lowest__Sales__##
q_0_min= min(q0_2010['Quarterly_Sales_0'])
q0_least_sales=q0_2010[q0_2010['Quarterly_Sales_0']==q_0]
q0_least_sales

q_1_min= min(q1_2010['Quarterly_Sales_1'])
q1_least_sales=q1_2010[q1_2010['Quarterly_Sales_1']==q_1]
q1_least_sales

q_2_min= min(q2_2010['Quarterly_Sales_2'])
q2_least_sales=q2_2010[q2_2010['Quarterly_Sales_2']==q_2]
q2_least_sales

q_3= min(q3_2010['Quarterly_Sales_3'])
q3_least_sales=q3_2010[q3_2010['Quarterly_Sales_3']==q_3]
q3_least_sales
# Out:
#        Quarterly_Sales_3
# Store
# 33            3588591.94

# %%
####yearly_quarter_wise_comparisin__#####
#########################################
q3_10=q3_2010.rename(columns={"Quarterly_Sales_3":"Quarterly_Sales_2010"})
q3_11=q3_2011.rename(columns={"Quarterly_Sales_3":"Quarterly_Sales_2011"})
q3_12=q3_2012.rename(columns={"Quarterly_Sales_3":"Quarterly_Sales_2012"})

q3_year_wise=pd.concat([q3_10,q3_11,q3_12],axis=1)
q3_year_wise['10_11']=((q3_year_wise['Quarterly_Sales_2011']/q3_year_wise['Quarterly_Sales_2010'])-1)*100
q3_year_wise['11_12']=((q3_year_wise['Quarterly_Sales_2012']/q3_year_wise['Quarterly_Sales_2011'])-1)*100
q3_year_wise
# Out:
#        Quarterly_Sales_2010  Quarterly_Sales_2011  Quarterly_Sales_2012  \
# Store
# 1               22583400.31           21574811.40            9580784.77
# 2               30034631.84           27105951.82           11470757.52
# 3                5834497.60            5596145.78            2537839.60
# 4               30798576.91           30747806.28           13075576.88
# 5                4628373.49            4414249.51            1948124.43
# 6               23735866.20           21876732.33            9053767.49
# 7                8356339.40            8639418.51            3215216.52
# 8               13728830.42           12784799.99            5591768.18
# 9                7929492.14            7890954.89            3391227.64
# 10              30315637.45           27798378.51           11084451.02
# 11              20235458.32           19204401.55            8008176.20
# 12              15214086.95           14574384.36            6096576.47
# ...

# %%
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-05-02    1643690.90             0        42.31       2.572
# 1      1 2010-12-02    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-05-03    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  month  Year  day
# 0  211.096358         8.106      5  2010    2
# 1  211.242170         8.106     12  2010    2
# 2  211.289143         8.106      2  2010   19
# 3  211.319643         8.106      2  2010   26
# 4  211.350143         8.106      5  2010    3

# %%
df["day"]=df["Date"].dt.day

# %%
df_holiday=pd.DataFrame(df.groupby(["Year","month","day"])["Weekly_Sales"].sum())

# %%
df_holiday.reset_index()
# Out:
#      Year  month  day  Weekly_Sales
# 0    2010      1   10   42239875.87
# 1    2010      2    4   50423831.26
# 2    2010      2    7   48917484.50
# 3    2010      2   19   48276993.78
# 4    2010      2   26   43968571.13
# ..    ...    ...  ...           ...
# 138  2012     10    8   47403451.04
# 139  2012     10   19   45122410.57
# 140  2012     10   26   45544116.29
# 141  2012     11    5   46925878.99
# 142  2012     12   10   46128514.25
#
# [143 rows x 4 columns]

# %%
np.mean(df["Weekly_Sales"])
# Out:
# 1046964.8775617732

# %%
from matplotlib import dates
from datetime import datetime
def plot_line(df,holiday_dates,holiday_label):
    fig, ax = plt.subplots(figsize = (15,5))  
    ax.plot(df['Date'],df['Weekly_Sales'],label=holiday_label)
    
    for day in holiday_dates:
        day = datetime.strptime(day, '%d-%m-%Y')
        plt.axvline(x=day, linestyle='--', c='r')
    

    plt.title(holiday_label)
    x_dates = df['Date'].dt.strftime('%Y-%m-%d').sort_values().unique()
    xfmt = dates.DateFormatter('%d-%m-%y')
    ax.xaxis.set_major_formatter(xfmt)
    ax.xaxis.set_major_locator(dates.DayLocator(1))
    plt.gcf().autofmt_xdate(rotation=90)
    plt.show()


total_sales = df.groupby('Date')['Weekly_Sales'].sum().reset_index()
Super_Bowl =['12-2-2010', '11-2-2011', '10-2-2012']
Labour_Day =  ['10-9-2010', '9-9-2011', '7-9-2012']
Thanksgiving =  ['26-11-2010', '25-11-2011', '23-11-2012']
Christmas = ['31-12-2010', '30-12-2011', '28-12-2012']
    
plot_line(total_sales,Super_Bowl,'Super Bowl')
plot_line(total_sales,Labour_Day,'Labour Day')
plot_line(total_sales,Thanksgiving,'Thanksgiving')
plot_line(total_sales,Christmas,'Christmas')

# %%
Super_Bowl_df = pd.DataFrame(df.loc[df.Date.isin(Super_Bowl)].groupby('Year')['Weekly_Sales'].sum())
Thanksgiving_df = pd.DataFrame(df.loc[df.Date.isin(Thanksgiving)].groupby('Year')['Weekly_Sales'].sum())
Labour_Day_df = pd.DataFrame(df.loc[df.Date.isin(Labour_Day)].groupby('Year')['Weekly_Sales'].sum())
Christmas_df = pd.DataFrame(df.loc[df.Date.isin(Christmas)].groupby('Year')['Weekly_Sales'].sum())

Super_Bowl_df.plot(kind='bar',legend=False,title='Yearly Sales in Super Bowl holiday') 
Thanksgiving_df.plot(kind='bar',legend=False,title='Yearly Sales in Thanksgiving holiday') 
Labour_Day_df.plot(kind='bar',legend=False,title='Yearly Sales in Labour_Day holiday')
Christmas_df.plot(kind='bar',legend=False,title='Yearly Sales in Christmas holiday')
# Out:
# <AxesSubplot:title={'center':'Yearly Sales in Christmas holiday'}, xlabel='Year'>
